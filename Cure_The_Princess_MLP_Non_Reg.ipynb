# %% [markdown]
# <a href="https://colab.research.google.com/github/ebubelk/Cure_The_Princess_MLP/blob/main/Cure_The_Princess_MLP_Non_Reg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import pandas as pd
import numpy as np
import random
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
import time

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
if device != "cuda":
  print("WARNING: For this notebook to perform best, "
        "if possible, in the menu under `Runtime` -> "
        "`Change runtime type.`  select `GPU` ")
else:
  print("GPU is enabled in this notebook.")
# Out:
# WARNING: For this notebook to perform best, if possible, in the menu under `Runtime` -> `Change runtime type.`  select `GPU`

# %%
def set_seed(seed=None, seed_torch=True):
  if seed is None:
    seed = np.random.choice(2 ** 32)
  random.seed(seed)
  np.random.seed(seed)
  if seed_torch:
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True
SEED = 190401072
set_seed(seed=SEED)

# %%
class CustomDataset(Dataset):
    def __init__(self, dataframe):
        self.data = dataframe.iloc[:, :-1].values
        self.targets = dataframe.iloc[:, -1].values

    def __len__(self):
        return len(self.data)

    def __getitem__(self, index):
        x = torch.Tensor(self.data[index])
        y = torch.Tensor([self.targets[index]])
        return x, y

trainset = CustomDataset(pd.read_csv('/content/cure_the_princess_train.csv'))
trainloader = DataLoader(trainset, batch_size=16, shuffle=True, num_workers=2)

valset = CustomDataset(pd.read_csv('/content/cure_the_princess_validation.csv'))
valloader = DataLoader(valset, batch_size=16, shuffle=False, num_workers=2)

testset = CustomDataset(pd.read_csv('/content/cure_the_princess_test.csv'))
testloader = DataLoader(testset, batch_size=16, shuffle=False, num_workers=2)

test_data = pd.read_csv('/content/cure_the_princess_test.csv')
test_value = test_data['Cured'].values

# %%
class MLP(nn.Module):
    def __init__(self):
        set_seed(seed=SEED)
        super(MLP, self).__init__()
        self.hidden_layer_first = nn.Linear(13, 100)
        self.hidden_layer_second = nn.Linear(100, 50)
        self.output_layer = nn.Linear(50, 1)
        self.relu = nn.ReLU() # ReLU aktivasyonu
        self.sigmoid = nn.Sigmoid() # sigmoid aktivasyonu
        
    def forward(self, x):
        x = self.relu(self.hidden_layer_first(x))
        x = self.relu(self.hidden_layer_second(x))
        x = self.sigmoid(self.output_layer(x))
        return x

# %%
start = time.time()
# Egitim parametreleri
learning_rate = 0.01
num_epochs = 200
patience = 100000000000

# Model, loss fonksiyonu ve optimizer olusturma
model = MLP()
model = model.to(device)
criterion = nn.BCELoss()
optimizer = optim.SGD(model.parameters(), lr=learning_rate)

# Egitim döngüsü
list_train_loss = []
list_val_loss = []
best_val_loss = None
patience_counter = 0

for epoch in range(num_epochs):
    train_loss = 0.0
    model.train() # train modunda modeli ayarla
    for inputs, labels in trainloader:
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
    
    train_loss /= len(trainloader)
    
    # Dogrulama seti uzerinde modelin performansini degerlendirme
    val_loss = 0.0
    model.eval() # eval modunda modeli ayarla
    with torch.no_grad():
        for inputs, labels in valloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
    
    val_loss /= len(valloader)
    
    print("Epoch", epoch, "Training loss", train_loss, "Validation Loss :", val_loss)
    
    list_train_loss.append(train_loss)
    list_val_loss.append(val_loss)
    
    val_score = val_loss
    if best_val_loss is None:
        best_val_loss = val_score
        torch.save(model.state_dict(), "checkpoint.pt")
    elif best_val_loss < val_score:
        patience_counter += 1
        print("Earlystopping Patience Counter:", patience_counter)
        if patience_counter == patience:
            print("Early stopping triggered.")
            break
    else:
        best_val_loss = val_score  # en iyi loss'u guncelle
        patience_counter = 0  # patience counter'i sifirla
torch.save(model.state_dict(), "last.pt")

sns.set_style("darkgrid")
plt.plot(list_train_loss, label="Train Loss")
plt.plot(list_val_loss, label="Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()
end = time.time()
print("Run time:", end - start)
# Out:
# Epoch 0 Training loss 0.5884003797663918 Validation Loss : 0.966483262181282
# Epoch 1 Training loss 0.426130165216289 Validation Loss : 0.33208912163972854
# Epoch 2 Training loss 0.32890377193689346 Validation Loss : 0.2758980251848698
# Epoch 3 Training loss 0.3001739493087877 Validation Loss : 0.6240473881363868
# Earlystopping Patience Counter: 1
# Epoch 4 Training loss 0.2754651800835434 Validation Loss : 0.43187856301665306
# Earlystopping Patience Counter: 2
# Epoch 5 Training loss 0.25318322311851044 Validation Loss : 0.20327940173447132
# Epoch 6 Training loss 0.24268302859007557 Validation Loss : 0.3459330350160599
# Earlystopping Patience Counter: 1
# Epoch 7 Training loss 0.21325947839436651 Validation Loss : 0.29303102716803553
# Earlystopping Patience Counter: 2
# Epoch 8 Training loss 0.20100537083948714 Validation Loss : 0.18028143160045146
# Epoch 9 Training loss 0.18104653857365438 Validation Loss : 0.1892580769956112
# Earlystopping Patience Counter: 1
# Epoch 10 Training loss 0.1696699898147696 Validation Loss : 0.284027411788702
# Earlystopping Patience Counter: 2
# Epoch 11 Training loss 0.16670993008191073 Validation Loss : 0.1758928606286645
# Epoch 12 Training loss 0.16119780386739138 Validation Loss : 0.5312384143471718
# Earlystopping Patience Counter: 1
# Epoch 13 Training loss 0.17065950964070573 Validation Loss : 0.1949872488155961
# Earlystopping Patience Counter: 2
# Epoch 14 Training loss 0.1513129446089645 Validation Loss : 0.3358350969851017
# Earlystopping Patience Counter: 3
# Epoch 15 Training loss 0.1469105757961545 Validation Loss : 0.1438141289167106
# Epoch 16 Training loss 0.13458652935827833 Validation Loss : 0.15356577467173338
# Earlystopping Patience Counter: 1
# Epoch 17 Training loss 0.12815219569432584 Validation Loss : 0.16224073395133018
# Earlystopping Patience Counter: 2
# Epoch 18 Training loss 0.12844581060300145 Validation Loss : 0.1501815477386117
# Earlystopping Patience Counter: 3
# Epoch 19 Training loss 0.116764118635579 Validation Loss : 0.16936619644984602
# Earlystopping Patience Counter: 4
# Epoch 20 Training loss 0.11686164722188458 Validation Loss : 0.21646247562021018
# Earlystopping Patience Counter: 5
# Epoch 21 Training loss 0.11819795779648083 Validation Loss : 0.33852321058511736
# Earlystopping Patience Counter: 6
# Epoch 22 Training loss 0.11823407613636949 Validation Loss : 0.17937824223190546
# Earlystopping Patience Counter: 7
# Epoch 23 Training loss 0.11084033067845091 Validation Loss : 0.15971605135127903
# Earlystopping Patience Counter: 8
# Epoch 24 Training loss 0.10309317494931194 Validation Loss : 0.41504660323262216
# Earlystopping Patience Counter: 9
# Epoch 25 Training loss 0.09978081234966558 Validation Loss : 0.15193814225494862
# Earlystopping Patience Counter: 10
# Epoch 26 Training loss 0.09934805715574493 Validation Loss : 0.16378107508644463
# Earlystopping Patience Counter: 11
# Epoch 27 Training loss 0.09264379989685892 Validation Loss : 0.13653046442195774
# Epoch 28 Training loss 0.08587185656533966 Validation Loss : 0.1295949670020491
# Epoch 29 Training loss 0.08521204555843355 Validation Loss : 0.20260522291064262
# Earlystopping Patience Counter: 1
# Epoch 30 Training loss 0.08415938855467152 Validation Loss : 0.30787970665842296
# Earlystopping Patience Counter: 2
# Epoch 31 Training loss 0.09475048254774529 Validation Loss : 0.14426716710440815
# Earlystopping Patience Counter: 3
# Epoch 32 Training loss 0.08165660766365973 Validation Loss : 0.1614428774919361
# Earlystopping Patience Counter: 4
# Epoch 33 Training loss 0.07815713922292748 Validation Loss : 0.2308178930543363
# Earlystopping Patience Counter: 5
# Epoch 34 Training loss 0.08549859105974814 Validation Loss : 0.16777102479245515
# Earlystopping Patience Counter: 6
# Epoch 35 Training loss 0.07306850998355902 Validation Loss : 0.17111696875654162
# Earlystopping Patience Counter: 7
# Epoch 36 Training loss 0.08039067001258836 Validation Loss : 0.3424867935478687
# Earlystopping Patience Counter: 8
# Epoch 37 Training loss 0.08003884705396581 Validation Loss : 0.16706926547922193
# Earlystopping Patience Counter: 9
# Epoch 38 Training loss 0.07483644571296777 Validation Loss : 0.19056514548137785
# Earlystopping Patience Counter: 10
# Epoch 39 Training loss 0.06960145311571564 Validation Loss : 0.28210287680849433
# Earlystopping Patience Counter: 11
# Epoch 40 Training loss 0.06533156257547156 Validation Loss : 0.17116815289482473
# Earlystopping Patience Counter: 12
# Epoch 41 Training loss 0.062155806922200546 Validation Loss : 0.19429644355550407
# Earlystopping Patience Counter: 13
# Epoch 42 Training loss 0.05695585042232341 Validation Loss : 0.1472756438422948
# Earlystopping Patience Counter: 14
# Epoch 43 Training loss 0.05557498127994602 Validation Loss : 0.1960973265580833
# Earlystopping Patience Counter: 15
# Epoch 44 Training loss 0.055516406383860524 Validation Loss : 0.1929441474378109
# Earlystopping Patience Counter: 16
# Epoch 45 Training loss 0.06049574395240862 Validation Loss : 0.16605513878166675
# Earlystopping Patience Counter: 17
# Epoch 46 Training loss 0.055266949850653266 Validation Loss : 0.18680412047542633
# Earlystopping Patience Counter: 18
# Epoch 47 Training loss 0.05266572532974938 Validation Loss : 1.0547245413064956
# Earlystopping Patience Counter: 19
# Epoch 48 Training loss 0.07647225385402105 Validation Loss : 0.16704906257800758
# Earlystopping Patience Counter: 20
# Epoch 49 Training loss 0.051514382300238255 Validation Loss : 0.16833326173946261
# Earlystopping Patience Counter: 21
# Epoch 50 Training loss 0.05487661471972065 Validation Loss : 0.16456689941696823
# Earlystopping Patience Counter: 22
# Epoch 51 Training loss 0.04646606528777865 Validation Loss : 0.17361141003202646
# Earlystopping Patience Counter: 49
# Epoch 78 Training loss 0.021759682347485206 Validation Loss : 0.22695891391485928
# Earlystopping Patience Counter: 50
# Epoch 79 Training loss 0.01980162010221636 Validation Loss : 0.20382533381925896
# Earlystopping Patience Counter: 51
# Epoch 80 Training loss 0.019896009130863167 Validation Loss : 0.20437144566094503
# Earlystopping Patience Counter: 52
# Epoch 81 Training loss 0.020901344807912843 Validation Loss : 0.19761220364598558
# Earlystopping Patience Counter: 53
# Epoch 82 Training loss 0.017592432469945945 Validation Loss : 0.20441424304735847
# Earlystopping Patience Counter: 54
# Epoch 83 Training loss 0.016752373909760455 Validation Loss : 0.1989949547103606
# Earlystopping Patience Counter: 55
# Epoch 84 Training loss 0.021548520199861674 Validation Loss : 0.2139785611536354
# Earlystopping Patience Counter: 56
# Epoch 85 Training loss 0.01750854582119073 Validation Loss : 0.19924093635054305
# Earlystopping Patience Counter: 57
# Epoch 86 Training loss 0.016871340975866806 Validation Loss : 0.2004478944814764
# Earlystopping Patience Counter: 58
# Epoch 87 Training loss 0.01674571946886651 Validation Loss : 0.20998142247553914
# Earlystopping Patience Counter: 59
# Epoch 88 Training loss 0.029498408222128934 Validation Loss : 0.23098822946194558
# Earlystopping Patience Counter: 60
# Epoch 89 Training loss 0.017823808606569597 Validation Loss : 0.22389342058449985
# Earlystopping Patience Counter: 61
# Epoch 90 Training loss 0.0139856653389686 Validation Loss : 0.20094667245866732
# Earlystopping Patience Counter: 62
# Epoch 91 Training loss 0.01621894275657597 Validation Loss : 0.2769019860192202
# Earlystopping Patience Counter: 63
# Epoch 92 Training loss 0.017661023356169286 Validation Loss : 0.2334390197065659
# Earlystopping Patience Counter: 64
# Epoch 93 Training loss 0.017665049179068096 Validation Loss : 0.207666799321305
# Earlystopping Patience Counter: 65
# Epoch 94 Training loss 0.013799002386896304 Validation Loss : 0.21396261924528517
# Earlystopping Patience Counter: 66
# Epoch 95 Training loss 0.01439297763379402 Validation Loss : 0.23279871804406865
# Earlystopping Patience Counter: 67
# Epoch 96 Training loss 0.013125109461723357 Validation Loss : 0.2144896580139175
# Earlystopping Patience Counter: 68
# Epoch 97 Training loss 0.011826534580536587 Validation Loss : 0.21525407672743313
# Earlystopping Patience Counter: 69
# Epoch 98 Training loss 0.01312199846916549 Validation Loss : 0.21822143668541685
# Earlystopping Patience Counter: 70
# Epoch 99 Training loss 0.012156058931752709 Validation Loss : 0.23430122229037806
# Earlystopping Patience Counter: 71
# Epoch 100 Training loss 0.011643403590213996 Validation Loss : 0.2175272634543944
# Earlystopping Patience Counter: 72
# Epoch 101 Training loss 0.01148092189783089 Validation Loss : 0.22114124036161228
# Earlystopping Patience Counter: 73
# Epoch 102 Training loss 0.01204782963982843 Validation Loss : 0.22422271153191103
# Earlystopping Patience Counter: 74
# Epoch 103 Training loss 0.01103501128312053 Validation Loss : 0.22618720892060082
# Earlystopping Patience Counter: 101
# Epoch 130 Training loss 0.017111829667325613 Validation Loss : 0.24550873374682852
# Earlystopping Patience Counter: 102
# Epoch 131 Training loss 0.007126410759593466 Validation Loss : 0.39328981113503686
# Earlystopping Patience Counter: 103
# Epoch 132 Training loss 0.013615445159338345 Validation Loss : 0.25961665230279324
# Earlystopping Patience Counter: 104
# Epoch 133 Training loss 0.0069804198055287165 Validation Loss : 0.25101572661369576
# Earlystopping Patience Counter: 105
# Epoch 134 Training loss 0.007371665059244024 Validation Loss : 0.24599280012771488
# Earlystopping Patience Counter: 106
# Epoch 135 Training loss 0.0062364118656878876 Validation Loss : 0.23801315682940186
# Earlystopping Patience Counter: 107
# Epoch 136 Training loss 0.005670053526069129 Validation Loss : 0.2523023475820082
# Earlystopping Patience Counter: 108
# Epoch 137 Training loss 0.005324821727310935 Validation Loss : 0.23935836937162094
# Earlystopping Patience Counter: 109
# Epoch 138 Training loss 0.006476882175314741 Validation Loss : 0.256012005606317
# Earlystopping Patience Counter: 110
# Epoch 139 Training loss 0.0061366239416098395 Validation Loss : 0.2445273804187309
# Earlystopping Patience Counter: 111
# Epoch 140 Training loss 0.0053208782999349695 Validation Loss : 0.2614575079685892
# Earlystopping Patience Counter: 112
# Epoch 141 Training loss 0.007043357715275893 Validation Loss : 0.2621072791313054
# Earlystopping Patience Counter: 113
# Epoch 142 Training loss 0.005143987154226608 Validation Loss : 0.2526972940046107
# Earlystopping Patience Counter: 114
# Epoch 143 Training loss 0.007305914327375083 Validation Loss : 0.2666198288367013
# Earlystopping Patience Counter: 115
# Epoch 144 Training loss 0.005601145764753883 Validation Loss : 0.2595850822865032
# Earlystopping Patience Counter: 116
# Epoch 145 Training loss 0.005411284122018676 Validation Loss : 0.24742418635869398
# Earlystopping Patience Counter: 117
# Epoch 146 Training loss 0.004637737178867772 Validation Loss : 0.2554999014508212
# Earlystopping Patience Counter: 118
# Epoch 147 Training loss 0.007874273399039925 Validation Loss : 0.2608250451085041
# Earlystopping Patience Counter: 119
# Epoch 148 Training loss 0.005717937159117148 Validation Loss : 0.26050961636210557
# Earlystopping Patience Counter: 120
# Epoch 149 Training loss 0.005597179463747343 Validation Loss : 0.26166041707037946
# Earlystopping Patience Counter: 121
# Epoch 150 Training loss 0.004654051751378022 Validation Loss : 0.2564552919822745
# Earlystopping Patience Counter: 122
# Epoch 151 Training loss 0.004412795798123602 Validation Loss : 0.26617605024657676
# Earlystopping Patience Counter: 123
# Epoch 152 Training loss 0.004163141336765058 Validation Loss : 0.26706657910399373
# Earlystopping Patience Counter: 124
# Epoch 153 Training loss 0.003775079848644135 Validation Loss : 0.2553210072030197
# Earlystopping Patience Counter: 125
# Epoch 154 Training loss 0.0038582454014497473 Validation Loss : 0.2608279298132402
# Earlystopping Patience Counter: 126
# Epoch 155 Training loss 0.003818219009604669 Validation Loss : 0.2582944284687983
# Earlystopping Patience Counter: 127
# Epoch 156 Training loss 0.0052817256145306 Validation Loss : 0.2652815023378935
# Earlystopping Patience Counter: 128
# Epoch 157 Training loss 0.004509746632673145 Validation Loss : 0.2613086313664098
# Earlystopping Patience Counter: 129
# Epoch 158 Training loss 0.003986343383024212 Validation Loss : 0.2632261568549438
# Earlystopping Patience Counter: 130
# Epoch 159 Training loss 0.003975880166325612 Validation Loss : 0.26253053688269573
# Earlystopping Patience Counter: 131
# Epoch 160 Training loss 0.003746756327409803 Validation Loss : 0.27128505734508507
# Earlystopping Patience Counter: 132
# Epoch 161 Training loss 0.004232895519264068 Validation Loss : 0.2587689923195285
# Earlystopping Patience Counter: 133
# Epoch 162 Training loss 0.003781842894625962 Validation Loss : 0.24306496824428905
# Earlystopping Patience Counter: 134
# Epoch 163 Training loss 0.004603202059979019 Validation Loss : 0.2604372835077811
# Earlystopping Patience Counter: 135
# Epoch 164 Training loss 0.003456283122083813 Validation Loss : 0.2611154595884727
# Earlystopping Patience Counter: 136
# Epoch 165 Training loss 0.003807671521746117 Validation Loss : 0.25841164647426923
# Earlystopping Patience Counter: 137
# Epoch 166 Training loss 0.0036433489813710285 Validation Loss : 0.2683155734470347
# Earlystopping Patience Counter: 138
# Epoch 167 Training loss 0.0036527710283194266 Validation Loss : 0.25583075916511006
# Earlystopping Patience Counter: 139
# Epoch 168 Training loss 0.0033409040928906704 Validation Loss : 0.28417668199545004
# Earlystopping Patience Counter: 140
# Epoch 169 Training loss 0.0031721528156813754 Validation Loss : 0.27563177026895574
# Earlystopping Patience Counter: 141
# Epoch 170 Training loss 0.0036194805078697684 Validation Loss : 0.2664132825957495
# Earlystopping Patience Counter: 142
# Epoch 171 Training loss 0.003437363589297046 Validation Loss : 0.27401076196256324
# Earlystopping Patience Counter: 143
# Epoch 172 Training loss 0.0032946148408699674 Validation Loss : 0.28505580434721195
# Earlystopping Patience Counter: 144
# Epoch 173 Training loss 0.0032668555111372314 Validation Loss : 0.2779655457437912
# Earlystopping Patience Counter: 145
# Epoch 174 Training loss 0.003473048936686172 Validation Loss : 0.27365898137068145
# Earlystopping Patience Counter: 146
# Epoch 175 Training loss 0.002916770874762884 Validation Loss : 0.2709794021531707
# Earlystopping Patience Counter: 147
# Epoch 176 Training loss 0.0031098864897621406 Validation Loss : 0.26496539031650174
# Earlystopping Patience Counter: 148
# Epoch 177 Training loss 0.0032779746033145185 Validation Loss : 0.26369755798368716
# Earlystopping Patience Counter: 149
# Epoch 178 Training loss 0.0031617356303458902 Validation Loss : 0.27448810310597765
# Earlystopping Patience Counter: 150
# Epoch 179 Training loss 0.00337097838571567 Validation Loss : 0.28028021742211423
# Earlystopping Patience Counter: 151
# Epoch 180 Training loss 0.0034582229315294425 Validation Loss : 0.3618660142965382
# Earlystopping Patience Counter: 152
# Epoch 181 Training loss 0.004418071959340132 Validation Loss : 0.27203647861315405
# Earlystopping Patience Counter: 153
# Epoch 182 Training loss 0.0032604898119298243 Validation Loss : 0.27248868095339274
# Earlystopping Patience Counter: 154
# Epoch 183 Training loss 0.002924198167040484 Validation Loss : 0.27919687800313114
# Earlystopping Patience Counter: 155
# Epoch 184 Training loss 0.0028677708053956976 Validation Loss : 0.28597697523146054
# Earlystopping Patience Counter: 156
# Epoch 185 Training loss 0.002674639304396932 Validation Loss : 0.27213523417303803
# Earlystopping Patience Counter: 157
# Epoch 186 Training loss 0.003299774412920946 Validation Loss : 0.27954464123467915
# Earlystopping Patience Counter: 158
# Epoch 187 Training loss 0.002727574781740167 Validation Loss : 0.2872515613154974
# Earlystopping Patience Counter: 159
# Epoch 188 Training loss 0.0025903050141700586 Validation Loss : 0.2919652882279479
# Earlystopping Patience Counter: 160
# Epoch 189 Training loss 0.002874586499608166 Validation Loss : 0.28400403135092345
# Earlystopping Patience Counter: 161
# Epoch 190 Training loss 0.002613721416590619 Validation Loss : 0.27985060294595315
# Earlystopping Patience Counter: 162
# Epoch 191 Training loss 0.0025652514472394787 Validation Loss : 0.2776020998615422
# Earlystopping Patience Counter: 163
# Epoch 192 Training loss 0.00248265392025652 Validation Loss : 0.27517309045942967
# Earlystopping Patience Counter: 164
# Epoch 193 Training loss 0.002616397771534933 Validation Loss : 0.27803045707260027
# Earlystopping Patience Counter: 165
# Epoch 194 Training loss 0.002572594532099466 Validation Loss : 0.2775853546670987
# Earlystopping Patience Counter: 166
# Epoch 195 Training loss 0.002421029671161624 Validation Loss : 0.2861832534603309
# Earlystopping Patience Counter: 167
# Epoch 196 Training loss 0.0024529073521051352 Validation Loss : 0.2918965149765427
# Earlystopping Patience Counter: 168
# Epoch 197 Training loss 0.002371625584278781 Validation Loss : 0.286531803010439
# Earlystopping Patience Counter: 169
# Epoch 198 Training loss 0.0023638389087671263 Validation Loss : 0.28508370570489205
# Earlystopping Patience Counter: 170
# Epoch 199 Training loss 0.0023988369618126843 Validation Loss : 0.2771442098412081
# Earlystopping Patience Counter: 171
# Run time: 125.24506878852844

# %%
device = "cpu"
model.to(device)
model.load_state_dict(torch.load("last.pt"))
model.eval()
test_loss = 0.0
outputs_list = []
with torch.no_grad():
    for inputs, labels in testloader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        test_loss += loss.item()
        outputs = (outputs >= 0.5).float()
        outputs_list.append(outputs)
test_loss /= len(testloader)
outputs_list = torch.cat(outputs_list, dim=0).numpy()
test_acc = accuracy_score(test_value, outputs_list)
test_f1 = f1_score(test_value, outputs_list, average='weighted')
test_precision = precision_score(test_value, outputs_list)
test_recall = recall_score(test_value, outputs_list)

print("Test Loss:", test_loss)
print("Test Accuracy:", test_acc)
print("Test F1 Score:", test_f1)
print("Test Precision Score:", test_precision)
print("Test Recall Score:", test_recall)
# Out:
# Test Loss: 0.19314109855652217
# Test Accuracy: 0.9572538860103627
# Test F1 Score: 0.9572334370662644
# Test Precision Score: 0.981029810298103
# Test Recall Score: 0.9329896907216495
